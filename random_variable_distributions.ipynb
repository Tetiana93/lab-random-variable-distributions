# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Tetiana\Documents\ironhack\lab\lab-random-variable-distributions\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv")
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
numerical = df.select_dtypes('number')
numerical
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
for col in df.select_dtypes('number'):
    sns.displot(df.select_dtypes('number')[col])
    plt.show()
# Out:
# C:\Users\Tetiana\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Tetiana\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Tetiana\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Tetiana\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Tetiana\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Tetiana\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %% [markdown]
# Columns: 'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies' - a discrete features; another columns - continious, have normal distribution.

# %%
numerical.columns
# Out:
# Index(['Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies',
#        'Total Claim Amount'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numerical_scaled = scaler.fit_transform(numerical)
numerical_scaled
# Out:
# array([[-0.76287773,  0.61282744, -0.70392465, ..., -0.42224956,
#         -0.82264788, -0.16963969],
#        [-0.14924546, -1.23961684,  0.02269103, ..., -0.42224956,
#          2.10615996,  2.400737  ],
#        [ 0.71063622,  0.36570978,  0.42959581, ..., -0.42224956,
#         -0.40424676,  0.45573376],
#        ...,
#        [ 0.02313483, -1.23961684, -0.23889062, ...,  2.87324529,
#         -0.40424676,  1.22793667],
#        [-0.06993547, -0.51735647,  0.08082028, ..., -0.42224956,
#          0.01415436,  0.88511256],
#        [-0.78495478, -1.23961684, -0.47140763, ..., -0.42224956,
#         -0.82264788, -0.22200449]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'numerical_scaled' is your scaled numerical data (a NumPy array)

# Set up subplots
fig, axes = plt.subplots(1, numerical_scaled.shape[1], figsize=(15, 4))

# Plot scaled data
for i in range(numerical_scaled.shape[1]):
    sns.histplot(numerical_scaled[:, i], kde=True, ax=axes[i])
    axes[i].set_title(f'Scaled - Column {i}')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# I don't see significant changes after scaling.
